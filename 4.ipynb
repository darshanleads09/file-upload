# %%
# Practical 4: Regression using FFNN

import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.metrics import r2_score, mean_absolute_error
from keras.models import Sequential
from keras.layers import Dense

# 1. Load dataset
df = pd.read_csv('Advertising.csv')

# 2. Data preprocessing
df.drop('ID', axis=1, inplace=True)   # remove ID column

X = df.iloc[:, :-1]   # input features
y = df.iloc[:, -1]    # target (sales)

# 3. Split data
xtrain, xtest, ytrain, ytest = train_test_split(X, y, test_size=0.2)

# 4. Build model
model = Sequential()
model.add(Dense(8, input_dim=3, activation='relu'))   # hidden layer 1
model.add(Dense(6, activation='relu'))                # hidden layer 2
model.add(Dense(1, activation='linear'))              # output layer

# 5. Compile model
model.compile(loss='mse', optimizer='adam')

# 6. Train model
model.fit(xtrain, ytrain, epochs=100, batch_size=32)

# 7. Predict
pred = model.predict(xtest)

# 8. Evaluate
print("R2 Score:", r2_score(ytest, pred))
print("MAE:", mean_absolute_error(ytest, pred))
# Out:
# Epoch 1/100
# C:\Users\Darshan\AppData\Local\Programs\Python\Python310\lib\site-packages\keras\src\layers\core\dense.py:95: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 368.4598
# Epoch 2/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 246.1378
# Epoch 3/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 165.1084
# Epoch 4/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 110.3609
# Epoch 5/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 88.2721
# Epoch 6/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 83.4831
# Epoch 7/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 81.6244
# Epoch 8/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 76.8816
# Epoch 9/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 69.2620
# ...
